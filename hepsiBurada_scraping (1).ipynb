
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 841 entries, 0 to 840
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Ürün_Linki     841 non-null    object
#  1   Ürün_Adı       841 non-null    object
#  2   Ürün_Fiyatı    841 non-null    object
#  3   Ürün_Puanı     841 non-null    object
#  4   Ürün_OySayısı  841 non-null    object
#  5   Ürün_Resmi     841 non-null    object
# dtypes: object(6)
# memory usage: 39.6+ KB

# %%
df.describe().T
# Out:
#               count unique                                                top  \
# Ürün_Linki      841    840  https://www.hepsiburada.com/torima-k55-kablosu...
# Ürün_Adı        841    788  Pirok Store Apple iPhone 13 Lansman Uyumlu Içi...
# Ürün_Fiyatı     841    533                                             699 TL
# Ürün_Puanı      841     27                                                4,8
# Ürün_OySayısı   841    382                                         Oylama yok
# Ürün_Resmi      841    826  https://productimages.hepsiburada.net/s/777/22...
#
#               freq
# Ürün_Linki       2
# Ürün_Adı         8
# Ürün_Fiyatı     51
# Ürün_Puanı     114
# Ürün_OySayısı   87
# Ürün_Resmi       4

# %%
df.dtypes
# Out:
# Ürün_Linki       object
# Ürün_Adı         object
# Ürün_Fiyatı      object
# Ürün_Puanı       object
# Ürün_OySayısı    object
# Ürün_Resmi       object
# dtype: object

# %%
df.columns
# Out:
# Index(['Ürün_Linki', 'Ürün_Adı', 'Ürün_Fiyatı', 'Ürün_Puanı', 'Ürün_OySayısı',
#        'Ürün_Resmi'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Ürün_Linki       0
# Ürün_Adı         0
# Ürün_Fiyatı      0
# Ürün_Puanı       0
# Ürün_OySayısı    0
# Ürün_Resmi       0
# dtype: int64

# %%
df['Ürün_Puanı'].value_counts() # group by(), count() SQL de
# Out:
# Ürün_Puanı
# 4,8         114
# 4,6         114
# 4,7         102
# 4,5          88
# Puan yok     87
# 4,4          75
# 4,3          47
# 5            44
# 4,9          32
# 4,2          27
# 4,1          21
# 4            19
# 3,9          14
# 3,7          11
# 3,4           7
# 3,8           7
# 3,5           7
# 3             6
# 3,1           5
# 3,6           4
# 3,3           3
# 2             2
# 2,5           1
# 2,7           1
# 3,2           1
# 2,8           1
# 1,9           1
# Name: count, dtype: int64

# %%
df.loc[df['Ürün_Puanı'] == 'Puan yok', 'Ürün_Puanı'] =  0

# %%
df.Ürün_Puanı.value_counts()
# Out:
# Ürün_Puanı
# 4,8    114
# 4,6    114
# 4,7    102
# 4,5     88
# 0       87
# 4,4     75
# 4,3     47
# 5       44
# 4,9     32
# 4,2     27
# 4,1     21
# 4       19
# 3,9     14
# 3,7     11
# 3,4      7
# 3,8      7
# 3,5      7
# 3        6
# 3,1      5
# 3,6      4
# 3,3      3
# 2        2
# 2,5      1
# 2,7      1
# 3,2      1
# 2,8      1
# 1,9      1
# Name: count, dtype: int64

# %%
df.Ürün_Puanı.dtype
# Out:
# dtype('O')

# %%
df['Ürün_Puanı'] = df['Ürün_Puanı'].str.replace(',', '.').astype(float)

# %%
df.Ürün_Puanı = df.Ürün_Puanı.astype('float')

# %%
df.Ürün_Puanı.dtype
# Out:
# dtype('float64')

# %%
df.Ürün_OySayısı.value_counts()
# Out:
# Ürün_OySayısı
# Oylama yok    87
# 5             11
# 6              9
# 17             8
# 25             8
#               ..
# 424            1
# 788            1
# 310            1
# 119            1
# 1099           1
# Name: count, Length: 382, dtype: int64

# %%
df.loc[df['Ürün_OySayısı'] == 'Oylama yok', 'Ürün_OySayısı'] =  0

# %%
df.Ürün_OySayısı.dtype
# Out:
# dtype('O')

# %%
df.Ürün_OySayısı = df.Ürün_OySayısı.astype('int')

# %%
df.Ürün_OySayısı.dtype
# Out:
# dtype('int64')

# %%
df.Ürün_OySayısı.value_counts()
# Out:
# Ürün_OySayısı
# 0       87
# 5       11
# 6        9
# 17       8
# 25       8
#         ..
# 424      1
# 788      1
# 310      1
# 119      1
# 1099     1
# Name: count, Length: 382, dtype: int64

# %%
df.Ürün_OySayısı.isnull().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#                                           Ürün_Linki  \
# 0  https://www.hepsiburada.com/iphone-13-128-gb-b...
# 1  https://adservice.hepsiburada.com/event/api/v1...
# 2  https://www.hepsiburada.com/samsung-galaxy-a16...
# 3  https://www.hepsiburada.com/spigen-48w-usb-c-2...
# 4  https://adservice.hepsiburada.com/event/api/v1...
#
#                                             Ürün_Adı Ürün_Fiyatı  Ürün_Puanı  \
# 0                       Apple iPhone 13 128 GB Beyaz   33.099 TL         4.8
# 1  Spigen iPhone 16 Kılıf Liquid Crystal MagFit M...      449 TL         4.6
# 2  Samsung Galaxy A16 128 GB 6 GB Ram (Samsung Tü...    8.699 TL         4.8
# 3  Spigen 45W USB-C 2 Port Mini Hızlı Şarj Aleti ...      399 TL         4.8
# 4  Etiget Samsung Galaxy S24 Ultra Tam Kaplayan A...   499,88 TL         5.0
#
#    Ürün_OySayısı                                         Ürün_Resmi
# 0          24550  https://productimages.hepsiburada.net/s/189/22...
# ...

# %%
df.Ürün_Fiyatı.dtype
# Out:
# dtype('O')

# %%
df.Ürün_Fiyatı.value_counts()
# Out:
# Ürün_Fiyatı
# 699 TL       51
# 657,06 TL    22
# 239,90 TL    16
# 184,49 TL     8
# 2.999 TL      8
#              ..
# 450 TL        1
# 577,42 TL     1
# 605,99 TL     1
# 150 TL        1
# 222,74 TL     1
# Name: count, Length: 533, dtype: int64

# %%
df.Ürün_Fiyatı.value_counts().get('Fiyat yok')
# Out:
# np.int64(1)

# %%
df.loc[df['Ürün_Fiyatı'] == 'Fiyat yok', 'Ürün_Fiyatı'] =  0

# %%
df.Ürün_Fiyatı = df.Ürün_Fiyatı.str.replace('.','').str.replace(',', '.').str.replace(' TL', '').astype(float)

# %%
df.Ürün_Fiyatı.dtype
# Out:
# dtype('float64')

# %%
df.Ürün_Fiyatı.value_counts()
# Out:
# Ürün_Fiyatı
# 699.00      51
# 657.06      22
# 239.90      16
# 2999.00      8
# 184.49       8
#             ..
# 79999.00     1
# 138.00       1
# 701.77       1
# 6999.00      1
# 59948.40     1
# Name: count, Length: 532, dtype: int64

# %%
df.describe().T
# Out:
#                count         mean           std   min     25%    50%     75%  \
# Ürün_Fiyatı    840.0  6954.903905  16586.374466  54.9  261.56  699.0  4054.0
# Ürün_Puanı     754.0     4.478117      0.427055   1.9    4.40    4.6     4.8
# Ürün_OySayısı  841.0   898.317479   2538.182200   0.0   23.00  147.0   747.0
#
#                     max
# Ürün_Fiyatı    116499.0
# Ürün_Puanı          5.0
# Ürün_OySayısı   41214.0

# %%
df.loc[df['Ürün_Fiyatı'].idxmax()]
# Out:
# Ürün_Linki       https://www.hepsiburada.com/iphone-16-pro-max-...
# Ürün_Adı                       Apple iPhone 16 Pro Max 512GB Siyah
# Ürün_Fiyatı                                               116499.0
# Ürün_Puanı                                                     4.8
# Ürün_OySayısı                                                  323
# Ürün_Resmi       https://productimages.hepsiburada.net/s/777/22...
# Name: 653, dtype: object

# %%
df.loc[df['Ürün_Fiyatı'].idxmin()]
# Out:
# Ürün_Linki       https://www.hepsiburada.com/gratell-type-c-hiz...
# Ürün_Adı         Gratell Type-C Hızlı Data ve Şarj Kablosu SİYA...
# Ürün_Fiyatı                                                   54.9
# Ürün_Puanı                                                     4.2
# Ürün_OySayısı                                                   35
# Ürün_Resmi       https://productimages.hepsiburada.net/s/777/22...
# Name: 219, dtype: object

# %%
df['Ürün_Fiyatı'].mean()
# Out:
# np.float64(6954.903904761905)

# %%
# Fiyat Dağılımı
plt.figure(figsize=(10,6))
sns.histplot(df['Ürün_Fiyatı'], bins=30)
plt.title('Fiyat Dağılımı')
plt.show()

# %%
# Puan-Fiyat Scatter Plot
plt.figure(figsize=(10,6))
sns.scatterplot(x='Ürün_Fiyatı', y='Ürün_Puanı', data=df)
plt.title('Fiyat vs Puan')
plt.show()

# %%
sayı = df['Ürün_Fiyatı'].mean()
float_deger = round(float(sayı), 2)
print(float_deger)
# Out:
# 6954.9

# %%
df.sort_values(by='Ürün_Puanı', ascending=False).head(10)
# Out:
#                                             Ürün_Linki  \
# 4    https://adservice.hepsiburada.com/event/api/v1...
# 333  https://www.hepsiburada.com/fibaks-honor-200-u...
# 334  https://www.hepsiburada.com/zoli-iphone-ve-and...
# 344  https://adservice.hepsiburada.com/event/api/v1...
# 766  https://www.hepsiburada.com/samsung-galaxy-s25...
# 775  https://www.hepsiburada.com/hoco-u123-regent-2...
# 52   https://www.hepsiburada.com/shaza-airglass-sam...
# 324  https://adservice.hepsiburada.com/event/api/v1...
# 408  https://www.hepsiburada.com/jopus-f9-arac-fm-t...
# 440  https://adservice.hepsiburada.com/event/api/v1...
#
#                                               Ürün_Adı  Ürün_Fiyatı  \
# 4    Etiget Samsung Galaxy S24 Ultra Tam Kaplayan A...       499.88
# 333  Fibaks Honor 200 Uyumlu Kılıf Kamera Korumalı ...       174.74
# 334  Zoli iPhone ve Android Uyumlu Type-C ve USB Gi...       339.15
# 344  Sneezy Apple Watch Uyumlu 40MM 4-5-6 Se Seri U...       213.99
# ...

# %%
df.sort_values(by='Ürün_OySayısı', ascending=False).head(5)
# Out:
#                                             Ürün_Linki  \
# 16   https://www.hepsiburada.com/apple-20-w-usb-c-g...
# 0    https://www.hepsiburada.com/iphone-13-128-gb-b...
# 9    https://www.hepsiburada.com/iphone-13-128-gb-s...
# 772  https://www.hepsiburada.com/anker-soundcore-h3...
# 24   https://www.hepsiburada.com/anker-soundcore-r5...
#
#                                               Ürün_Adı  Ürün_Fiyatı  \
# 16   Apple 20 W USB-C Güç Adaptörü - MUVV3TU/A (App...       541.99
# 0                         Apple iPhone 13 128 GB Beyaz     33099.00
# 9                         Apple iPhone 13 128 GB Siyah     32899.00
# 772  Anker Soundcore H30i Mikrofonlu Kablosuz Kulak...      1629.00
# 24   Anker Soundcore R50i TWS Bluetooth Kablosuz Ku...       909.00
#
#      Ürün_Puanı  Ürün_OySayısı  \
# 16          4.7          41214
# 0           4.8          24550
# 9           4.8          24550
# 772         4.7          20705
# 24          4.6          15163
#
# ...

# %%
df[df['Ürün_Adı'].str.contains('apple', case=False, na=False)].sort_values(by='Ürün_Fiyatı', ascending=False).head(10)
# Out:
#                                             Ürün_Linki  \
